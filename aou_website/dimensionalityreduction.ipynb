# %% [markdown]
# ---
# title: "Dimensionality Reduction"
# ---

# %% [markdown]
# # Project Proposal

# %% [markdown]
# A brief proposal outlining your project’s objectives, dataset selection, and the tools or libraries you plan to use (e.g., Python, scikit-learn).
#
# With dimensionality reduction, my goal is to decide the optimal features needed to get the best idea of patterns in my dataset. My feature data includes the chart position of an artist, the length of time the artist has been at their position on the charts, the amount of times the artist maintained that position, the points accumulated, and the rank in their country. As well as my target data representing the highest position that specific song by the artist has reached on the charts. For dimensionality reduction, I will implement Principal Components Analysis (PCA) and t- Distirbuted Stochastic Neighbor Embedding (t-SNE) on my data. The libraries I will use include Pandas and Numpy for structre and computation of my data, Seaborn and Matplotlib.pyplot for visualization, and various packages from Sci- kit Learn. These include sklearn.decomposition to access PCA and sklearn- manifold to access t- SNE.

# %%
import requests
import json
import re
#import pycountry
import pandas as pd
import numpy as np

appledf = pd.read_csv("../websitedata/apple_py.csv")

newAppledf = pd.read_csv("../websitedata/newApple_py.csv")

# %%
y = appledf["Peak"]
y=np.array(y)

x= newAppledf.drop(columns="Peak")
# Out:
# <bound method NDFrame.head of      Unnamed: 0  Chart Position  Position Duration  Peak  (x?)  Points  \
# 0             0               1                 68     1    45   16920
# 1             1               2                 27     2     9   14619
# 2             2               3                  6     3     1   13364
# 3             3               4                  6     3     2   12624
# 4             4               5                  6     2     2   12359
# ..          ...             ...                ...   ...   ...     ...
# 831         831               7                245     1    13   10731
# 832         832              30                 90     2    10    5425
# 833         833              33                356     1    50    5108
# 834         834              62                412     3    13    2739
# 835         835              70                307     1     3    2487
#
#      Country Rank
# 0              29
# 1              44
# 2               1
# ...

# %% [markdown]
# ### PCA

# %% [markdown]
# Dimensionality Reduction with PCA:
# Apply PCA to your record dataset.
# Determine the optimal number of principal components to retain.
# Visualize the reduced-dimensional data using PCA.
# Analyze and interpret the results.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ####GET DATASET
# from keras.datasets import mnist
# (X, Y), (test_images, test_labels) = mnist.load_data()


from sklearn.datasets import load_digits
# LOAD DATA
X= newAppledf
Y= y

print(X.shape)

#NORMALIZE AND RESHAPE
X=X/np.max(X) #NORMALIZE
# X=X.reshape(60000,28*28); #print(X[0])

#COMPUTE PCA
from sklearn.decomposition import PCA
n_components=5
pca = PCA(n_components=n_components)
# pca.fit(X)
X1=pca.fit_transform(X)

#2D PLOT
plt.scatter(X1[:,1], X1[:,2], c=Y, cmap='tab10')
plt.show()
# Out:
# (836, 7)

# %% [markdown]
# ### t- SNE at Different Perplexity Values

# %% [markdown]
# Dimensionality Reduction with t-SNE:
# Implement t-SNE on the same dataset.
# Explore different perplexity values and their impact.
# Visualize the t-SNE output to reveal patterns and clusters.
# Compare t-SNE results with PCA results.

# %%
from sklearn.datasets import load_digits
import numpy as np
from sklearn.manifold import TSNE
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

# LOAD DATA
print("LOAD MNIST DATA")
X= newAppledf
print(X.shape)

# DO DIMENSIONALITY REDUCTION
X_embedded = TSNE(n_components=2, learning_rate='auto',init='random', perplexity=7).fit_transform(X)

# EXPLORE RESULTS
print("RESULTS") 
print("shape : ",X_embedded.shape)
print("First few points : \n",X_embedded[0:2,:])

# PLOT 
plt.scatter(X_embedded[:,0],X_embedded[:,1], alpha=0.5)
plt.show()
# Out:
# LOAD MNIST DATA
# (836, 7)
# RESULTS
# shape :  (836, 2)
# First few points :
#  [[ 14.800928  12.059045]
#  [-17.386383 -10.151677]]

# %%
from sklearn.datasets import load_digits
import numpy as np
from sklearn.manifold import TSNE
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

# LOAD DATA
print("LOAD MNIST DATA")
X= newAppledf
print(X.shape)

# DO DIMENSIONALITY REDUCTION
X_embedded = TSNE(n_components=2, learning_rate='auto',init='random', perplexity=15).fit_transform(X)

# EXPLORE RESULTS
print("RESULTS") 
print("shape : ",X_embedded.shape)
print("First few points : \n",X_embedded[0:2,:])

# PLOT 
plt.scatter(X_embedded[:,0],X_embedded[:,1], alpha=0.5)
plt.show()
# Out:
# LOAD MNIST DATA
# (836, 7)
# RESULTS
# shape :  (836, 2)
# First few points :
#  [[-12.221711 -35.10888 ]
#  [ 13.078242  35.452816]]

# %%
from sklearn.datasets import load_digits
import numpy as np
from sklearn.manifold import TSNE
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

# LOAD DATA
print("LOAD MNIST DATA")
X= newAppledf
print(X.shape)

# DO DIMENSIONALITY REDUCTION
X_embedded = TSNE(n_components=2, learning_rate='auto',init='random', perplexity=30).fit_transform(X)

# EXPLORE RESULTS
print("RESULTS") 
print("shape : ",X_embedded.shape)
print("First few points : \n",X_embedded[0:2,:])

# PLOT 
plt.scatter(X_embedded[:,0],X_embedded[:,1], alpha=0.5)
plt.show()
# Out:
# LOAD MNIST DATA
# (836, 7)
# RESULTS
# shape :  (836, 2)
# First few points :
#  [[28.993742  4.609136]
#  [23.607738 26.252493]]

# %% [markdown]
# As the perplexity increases, the clusters become smaller and more apparent.

# %% [markdown]
# # Project Report

# %% [markdown]
# A comprehensive project report detailing the steps taken, results obtained, and your analysis.
# Include visualizations, comparisons, and insights gained from the dimensionality reduction techniques.
#
# After running the PCA and t- SNE analyses on my data, I see an increase in distinct clusters as the perplexit increases. I will have more conclusions drawn when I add more visualizations to my comparison.
